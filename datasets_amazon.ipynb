# %%
import os
import kagglehub

# %%
# Establecer el directorio de descarga
os.environ['KAGGLE_DATA_DIR'] = '/home/miguel-oscar/DS_IBM_Course/DS_IBM_Course/Tarea_2-Maestria'

# %% [markdown]
# ### Amazon Product Reviews Dataset

# %%
# Descargar el dataset
path = kagglehub.dataset_download("yasserh/amazon-product-reviews-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/miguel-oscar/.cache/kagglehub/datasets/yasserh/amazon-product-reviews-dataset/versions/1

# %%
import pandas as pd

df = pd.read_csv('/home/miguel-oscar/DS_IBM_Course/DS_IBM_Course/Tarea_2-Maestria/7817_1.csv')

df.head()
# Out:
#                      id       asins   brand                  categories  \
# 0  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 1  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 2  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 3  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 4  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
#
#   colors             dateAdded           dateUpdated  \
# 0    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 1    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 2    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 3    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 4    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
#
#                   dimension  ean                         keys  ...  \
# 0  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# 1  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# ...

# %%
df.shape
# Out:
# (1597, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1597 non-null   object
#  1   asins                 1597 non-null   object
#  2   brand                 1597 non-null   object
#  3   categories            1597 non-null   object
#  4   colors                774 non-null    object
#  5   dateAdded             1597 non-null   object
#  6   dateUpdated           1597 non-null   object
#  7   dimension             565 non-null    object
#  8   ean                   898 non-null    float64
#  9   keys                  1597 non-null   object
#  10  manufacturer          965 non-null    object
#  11  manufacturerNumber    902 non-null    object
#  12  name                  1597 non-null   object
#  13  prices                1597 non-null   object
#  14  reviews.date          1217 non-null   object
# ...

# %% [markdown]
# ### Amazon Best Sellers

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("edwardtoledolpez/amazon-mexico-top-50-best-sellers")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/miguel-oscar/.cache/kagglehub/datasets/edwardtoledolpez/amazon-mexico-top-50-best-sellers/versions/2

# %%
import pandas as pd
df1 = pd.read_csv('/home/miguel-oscar/DS_IBM_Course/DS_IBM_Course/Tarea_2-Maestria/mx-amazon-devices.csv', sep='|',on_bad_lines='skip')

df1.head()
# Out:
#    Unnamed: 0              time  Rank  \
# 0           0  2020-07-31 00:38   1.0
# 1           1  2020-07-31 00:38   2.0
# 2           2  2020-07-31 00:38   3.0
# 3           3  2020-07-31 00:38   4.0
# 4           4  2020-07-31 00:38   5.0
#
#                                        Product Names  Stars  Reviews  \
# 0  Echo Dot (3ra generación) - Bocina inteligente...    4.8  26999.0
# 1  Fire TV Stick - Reproductor de media con contr...    4.6   8273.0
# 2             Amazon Smart Plug compatible con Alexa    4.8   4891.0
# 3  E-reader Kindle Paperwhite, resistente al agua...    4.8   3388.0
# 4  Nuevo e-reader Kindle, ahora con una luz front...    4.8   2803.0
#
#    Authors/Company  Edition/Console  Price_std_or_min  Max_prices
# 0              NaN              NaN             999.0      1499.0
# 1              NaN              NaN             999.0         NaN
# 2              NaN              NaN             550.0         NaN
# ...

# %%
import requests

params = {
    'api_key': 'FB08646943704A4699589263D9C00518',
    'amazon_domain': 'amazon.com',
    'type': 'product',
    'asin': 'B07J4TNYV8'
}

response = requests.get('https://api.rainforestapi.com/request', params=params)
producto = response.json()

# Acceder a datos específicos
titulo = producto['product']['title']
precio = producto['product']['buybox_winner']['price']['value']
rating = producto['product']['rating']

# %%
titulo, precio, rating

# %%
producto
